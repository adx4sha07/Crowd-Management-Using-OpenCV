# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in /opt/anaconda3/lib/python3.12/site-packages (2.98)
# Requirement already satisfied: pyobjc>=2.4 in /opt/anaconda3/lib/python3.12/site-packages (from pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-core==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Automator==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreData==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreText==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Quartz==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Security==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-WebKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NetFS==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-libxpc==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Accounts==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-EventKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Social==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AVKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameController==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MapKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Contacts==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Metal==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Photos==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Intents==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreML==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Vision==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Network==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-OSLog==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PushKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Speech==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AdServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CallKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PassKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MailKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PHASE==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Symbols==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-BrowserEngineKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#opening the live photo frontal face
import cv2
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + '`.xml')

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Can't receive frame (stream end?). Exiting ...")
        break
    

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2) 

    
    cv2.imshow('Face Detection', frame)
    
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# [ERROR:0@1489.847] global persistence.cpp:531 open Can't open file: '/opt/anaconda3/lib/python3.12/site-packages/cv2/data/`.xml' in read mode
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[19], line 23
#      17     break
#      20 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# ---> 23 faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
#      26 for (x, y, w, h) in faces:
#      27     cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
#
# error: OpenCV(4.10.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
#frontal and backward version
import cv2

# Load the pre-trained Haar Cascade classifiers for face and upper body detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
upperbody_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_upperbody.xml')

# Initialize the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # If frame is read correctly, ret is True
    if not ret:
        print("Error: Can't receive frame (stream end?). Exiting ...")
        break
    
    # Convert frame to grayscale (Haar Cascade works on grayscale images)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # If no faces are detected, try detecting upper bodies
    if len(faces) == 0:
        upper_bodies = upperbody_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        for (x, y, w, h) in upper_bodies:
            # Draw a rectangle around the detected upper body (back of the head approximation)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(frame, 'Back of Head Detected', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            # Save the image when back of the head is detected
            cv2.imwrite('back_of_head.png', frame)
    else:
        # Draw a rectangle around each detected face
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)  # Blue rectangle for face
            cv2.putText(frame, 'Face Detected', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
            # Save the image when a face is detected
            cv2.imwrite('face_detected.png', frame)

    # Display the frame with rectangles
    cv2.imshow('Face and Head Detection', frame)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
#setting threshold so that it will display the crowd
import cv2
# Load the pre-trained Haar Cascade classifiers for face and upper body detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
upperbody_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_upperbody.xml')

# Initialize the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Set the threshold for overcrowding
crowd_threshold = 5  # You can adjust this limit as needed

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # If frame is read correctly, ret is True
    if not ret:
        print("Error: Can't receive frame (stream end?). Exiting ...")
        break
    
    # Convert frame to grayscale (Haar Cascade works on grayscale images)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    num_individuals = len(faces)  # Start counting the number of detected individuals with faces

    # If no faces are detected, try detecting upper bodies
    if num_individuals == 0:
        upper_bodies = upperbody_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        num_individuals += len(upper_bodies)  # Add the detected upper bodies to the count
        for (x, y, w, h) in upper_bodies:
            # Draw a rectangle around the detected upper body (back of the head approximation)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(frame, 'Back of Head Detected', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            # Save the image when back of the head is detected
            cv2.imwrite('back_of_head.png', frame)
    else:
        # Draw a rectangle around each detected face
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)  # Blue rectangle for face
            cv2.putText(frame, 'Face Detected', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
            # Save the image when a face is detected
            cv2.imwrite('face_detected.png', frame)

    # Check if the count exceeds the threshold and display overcrowding warning
    if num_individuals > crowd_threshold:
        cv2.putText(frame, 'Warning: Overcrowded!', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    else:
        cv2.putText(frame, f'Occupancy: {num_individuals}/{crowd_threshold}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Display the frame with rectangles
    cv2.imshow('Face and Head Detection', frame)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
#voice assistant feature
import cv2
import pyttsx3

# Load the pre-trained Haar Cascade classifiers for face and upper body detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
upperbody_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_upperbody.xml')

# Initialize the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Initialize text-to-speech engine
engine = pyttsx3.init()

# Set the threshold for overcrowding
crowd_threshold = 5  # You can adjust this limit as needed
last_announcement = ""  # Track the last announcement to avoid repetitive announcements

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # If frame is read correctly, ret is True
    if not ret:
        print("Error: Can't receive frame (stream end?). Exiting ...")
        break
    
    # Convert frame to grayscale (Haar Cascade works on grayscale images)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    num_individuals = len(faces)  # Start counting the number of detected individuals with faces

    # If no faces are detected, try detecting upper bodies
    if num_individuals == 0:
        upper_bodies = upperbody_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        num_individuals += len(upper_bodies)  # Add the detected upper bodies to the count
        for (x, y, w, h) in upper_bodies:
            # Draw a rectangle around the detected upper body (back of the head approximation)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(frame, 'Back of Head Detected', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            # Save the image when back of the head is detected
            cv2.imwrite('back_of_head.png', frame)
    else:
        # Draw a rectangle around each detected face
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)  # Blue rectangle for face
            cv2.putText(frame, 'Face Detected', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
            # Save the image when a face is detected
            cv2.imwrite('face_detected.png', frame)

    # Check if the count exceeds the threshold and display overcrowding warning
    if num_individuals > crowd_threshold:
        cv2.putText(frame, 'Warning: Overcrowded!', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        announcement = f"Warning: Overcrowded! {num_individuals} individuals detected."
    else:
        cv2.putText(frame, f'Occupancy: {num_individuals}/{crowd_threshold}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        announcement = f"{num_individuals} individuals detected. The occupancy is within the safe limit."

    # Make the voice announcement only if it's different from the last announcement
    if announcement != last_announcement:
        engine.say(announcement)
        engine.runAndWait()
        last_announcement = announcement  # Update last announcement to avoid repetition

    # Display the frame with rectangles
    cv2.imshow('Face and Head Detection', frame)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 2024-11-29 01:06:31.723 python[10759:470197] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# objc[10759]: class `NSKVONotifying_AVCaptureConnection' not linked into application
# objc[10759]: class `NSKVONotifying_AVCaptureSession' not linked into application
# objc[10759]: class `NSKVONotifying_AVCaptureVideoDataOutput' not linked into application
# objc[10759]: class `NSKVONotifying_AVCaptureInputPort' not linked into application
# objc[10759]: class `NSKVONotifying_AVCaptureDeviceInput' not linked into application
# 2024-11-29 01:06:51.367 python[10759:470197] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-11-29 01:06:51.368 python[10759:470197] +[IMKInputSession subclass]: chose IMKInputSession_Modern
